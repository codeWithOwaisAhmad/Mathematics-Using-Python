# %%
import csv
from itertools import count
import operator
import math

EPSILON = 0.000001


def calc_term_doc_given_author(prob_map, counts):
    """
    How likely is the document, given the counts of words in the doc
    and the authors prob_map
    """
    prob = 1
    return prob


# If a word is in a probability dictionary, return its probability
# otherwise, return epsilon
def get_word_prob(word_prob_map, word):
    """
    Gets probability of a word:
    Returns probability if word exists, EPSILON if not
    """
    if word in word_prob_map:
        return word_prob_map[word]
    #return EPSILON

# From a file name, approximate the probability of a word
# being generated from the same distribution as the file.
# Assume that each word is produced independently, regardless
# of order.
def make_word_prob_map(fileName):
    """
    Calculates word probabilities:
    1. Counts word frequencies
    2. Converts counts to probabilities
    Returns: word probability dictionary
    """
    wordMap, nWords = make_word_count_map(fileName)
    probabilityMap = {}
    for word in wordMap:
        count = wordMap[word]
        p = float(count) / nWords
        probabilityMap[word] = p
    return probabilityMap

# From a file name, count the number of times each word exists
# in that file. Return the result as a map (aka a dictionary)
def make_word_count_map(fileName):
    """
    Reads a file and counts word frequencies:
    1. Opens file
    2. Splits into words
    3. Standardizes each word
    4. Counts occurrences
    Returns: (wordMap, total word count)
    """
    wordMap = {}
    nWords = 0
    with open(fileName ,encoding="utf-8") as f:
        for line in f:
            words = line.split(' ')
            for word in words:
                word = standardize(word)
                add_word_to_count_map(wordMap, word)
                nWords+= 1
    return wordMap, nWords

# Add a word to a count map. Makes sure not to crash if the
# word has not been seen before.
def add_word_to_count_map(wordMap, word):
    """
    Updates word count in dictionary:
    1. Skips stop words
    2. Initializes count if new word
    3. Increments count if existing word
    """
    if is_stop(word):
        return
    if not word in wordMap:
        wordMap[word] = 0
    wordMap[word] += 1


def standardize(word):
    """
    Standardizes words by:
    1. Converting to lowercase
    2. Removing punctuation
    3. Keeping only alphabetic characters
    """
    standard = word.lower().strip()
    # remove punctuation
    standard = ''.join([i for i in standard if i.isalpha()])
    return standard

def is_stop(word):
    """
    Removes common words that don't help in analysis
    """
    stop_words = ['to', 'i', 'the', 'and', 'of']
    return word in stop_words


def main():
    # Calculate all the ps and qs
    # Eg hamiltonWordProb['congress'] = 0.005
    # hamilton_word_prob['piech'] = 0.0
    # hamilton_word_prob['the'] = 0.001

    hamilton_word_prob = make_word_prob_map('hamilton.txt')
    madison_word_prob = make_word_prob_map('madison.txt')

    

    # Get the word count of the unknown document
    # Eg unknown_doc_count['congress'] = 5
    unknown_doc_count, n_words = make_word_count_map('unknown.txt')

    print("hamilton['congress']\t", hamilton_word_prob['congress'])
    print("madison['congress']\t",  madison_word_prob['congress'])
    print("doc_count['congress']\t", unknown_doc_count['congress'])
    print("n_words", n_words)

    hamilton_term = calc_term_doc_given_author(hamilton_word_prob, unknown_doc_count)
    print('---'*10)
    madison_term = calc_term_doc_given_author(madison_word_prob, unknown_doc_count)
    print("Hamilton Term\t", hamilton_term)
    print("Madison Term\t",madison_term)

if __name__ == '__main__':
    main()
# Out:
# n_words 1112
# ------------------------------
# Hamilton Term	 1
# Madison Term	 1

# %%
import csv
from itertools import count
import operator
import math

EPSILON = 0.000001



def calc_term_doc_given_author(prob_map, counts):
    """
    How likely is the document, given the counts of words in the doc
    and the authors prob_map
    """
    prob = 1
    for word, c_i in counts.items():
        p_word = get_word_prob(prob_map, word)
        prob *= p_word ** c_i
        print("word: ", word,"| prob_word: ", p_word, "| c_i: ", c_i, "| prob: ", prob)
    return prob
    # prob = 0
    # for word, c_i in counts.items():
    #     p_word = get_word_prob(prob_map, word)
    #     prob += math.log(p_word) * c_i
    # return prob


# If a word is in a probability dictionary, return its probability
# otherwise, return epsilon
def get_word_prob(word_prob_map, word):
    if word in word_prob_map:
        return word_prob_map[word]
    return EPSILON

# From a file name, approximate the probability of a word
# being generated from the same distribution as the file.
# Assume that each word is produced independently, regardless
# of order.
def make_word_prob_map(fileName):
    wordMap, nWords = make_word_count_map(fileName)
    probabilityMap = {}
    for word in wordMap:
        count = wordMap[word]
        p = float(count) / nWords
        probabilityMap[word] = p
    return probabilityMap

# From a file name, count the number of times each word exists
# in that file. Return the result as a map (aka a dictionary)
def make_word_count_map(fileName):
    wordMap = {}
    nWords = 0
    with open(fileName ,encoding='utf-8') as f:
        for line in f:
            words = line.split(' ')
            for word in words:
                word = standardize(word)
                add_word_to_count_map(wordMap, word)
                nWords+= 1
    return wordMap, nWords

# Add a word to a count map. Makes sure not to crash if the
# word has not been seen before.
def add_word_to_count_map(wordMap, word):
    if is_stop(word):
        return
    if not word in wordMap:
        wordMap[word] = 0
    wordMap[word] += 1

# Standardizes a word. For now, we are just going to make it
# lower case.
def standardize(word):
    standard = word.lower().strip()
    # remove punctuation
    standard = ''.join([i for i in standard if i.isalpha()])
    return standard

def is_stop(word):
    stop_words = ['to', 'i', 'the', 'and', 'of']
    return word in stop_words

def main():
    # Calculate all the ps and qs
    # Eg hamiltonWordProb['congress'] = 0.005
    # hamilton_word_prob['piech'] = 0.0
    # hamilton_word_prob['the'] = 0.001

    hamilton_word_prob = make_word_prob_map('hamilton.txt')
    madison_word_prob = make_word_prob_map('madison.txt')

    

    # Get the word count of the unknown document
    # Eg unknown_doc_count['congress'] = 5
    unknown_doc_count, n_words = make_word_count_map('unknown.txt')

    #print("hamilton['congress']\t", hamilton_word_prob['congress'])
    #print("madison['congress']\t",  madison_word_prob['congress'])
    #print("doc_count['congress']\t", unknown_doc_count['congress'])
    print("n_words", n_words)

    hamilton_term = calc_term_doc_given_author(hamilton_word_prob, unknown_doc_count)
    print('---'*10)
    madison_term = calc_term_doc_given_author(madison_word_prob, unknown_doc_count)
    print("Hamilton Term\t", hamilton_term)
    print("Madison Term\t",madison_term)

if __name__ == '__main__':
    main()
# Out:
# n_words 1112
# word:  everchanging | prob_word:  1e-06 | c_i:  2 | prob:  1e-12
# word:  landscape | prob_word:  0.0011376564277588168 | c_i:  2 | prob:  1.294262147620952e-18
# word:  global | prob_word:  0.012514220705346985 | c_i:  8 | prob:  7.784894483745558e-34
# word:  affairs | prob_word:  0.004550625711035267 | c_i:  2 | prob:  1.6121110805656044e-38
# word:   | prob_word:  0.04209328782707622 | c_i:  43 | prob:  1.1182720485364787e-97
# word:  in | prob_word:  0.015927189988623434 | c_i:  19 | prob:  7.748034060716292e-132
# word:  a | prob_word:  0.012514220705346985 | c_i:  18 | prob:  4.389955346677659e-166
# word:  world | prob_word:  0.004550625711035267 | c_i:  6 | prob:  3.898403607633612e-180
# word:  that | prob_word:  1e-06 | c_i:  2 | prob:  3.898403607633612e-192
# word:  never | prob_word:  1e-06 | c_i:  1 | prob:  3.898403607633612e-198
# word:  stands | prob_word:  1e-06 | c_i:  1 | prob:  3.8984036076336115e-204
# word:  still | prob_word:  1e-06 | c_i:  3 | prob:  3.898403607633611e-222
# word:  rapid | prob_word:  0.0022753128555176336 | c_i:  2 | prob:  2.0182224902036576e-227
# word:  pace | prob_word:  1e-06 | c_i:  2 | prob:  2.0182224902036577e-239
# word:  events | prob_word:  0.004550625711035267 | c_i:  2 | prob:  4.1793743592766266e-244
# word:  continues | prob_word:  0.0034129692832764505 | c_i:  4 | prob:  5.670753800922989e-254
# word:  shape | prob_word:  1e-06 | c_i:  1 | prob:  5.670753800922989e-260
# word:  our | prob_word:  1e-06 | c_i:  1 | prob:  5.6707538009229885e-266
# word:  daily | prob_word:  1e-06 | c_i:  1 | prob:  5.670753800922988e-272
# word:  lives | prob_word:  1e-06 | c_i:  1 | prob:  5.670753800922988e-278
# word:  unexpected | prob_word:  1e-06 | c_i:  1 | prob:  5.670753800922987e-284
# word:  ways | prob_word:  1e-06 | c_i:  1 | prob:  5.670753800922987e-290
# word:  political | prob_word:  0.0022753128555176336 | c_i:  3 | prob:  6.679810687610704e-298
# word:  power | prob_word:  1e-06 | c_i:  5 | prob:  0.0
# word:  shifts | prob_word:  1e-06 | c_i:  2 | prob:  0.0
# word:  economic | prob_word:  0.007963594994311717 | c_i:  8 | prob:  0.0
# word:  struggles | prob_word:  1e-06 | c_i:  3 | prob:  0.0
# word:  technological | prob_word:  0.005688282138794084 | c_i:  4 | prob:  0.0
# word:  breakthroughs | prob_word:  0.0011376564277588168 | c_i:  2 | prob:  0.0
# word:  environmental | prob_word:  0.0011376564277588168 | c_i:  2 | prob:  0.0
# word:  concerns | prob_word:  0.0034129692832764505 | c_i:  5 | prob:  0.0
# word:  all | prob_word:  1e-06 | c_i:  1 | prob:  0.0
# word:  collide | prob_word:  1e-06 | c_i:  1 | prob:  0.0
# word:  complex | prob_word:  1e-06 | c_i:  1 | prob:  0.0
# word:  web | prob_word:  1e-06 | c_i:  1 | prob:  0.0
# word:  demands | prob_word:  1e-06 | c_i:  2 | prob:  0.0
# word:  constant | prob_word:  1e-06 | c_i:  1 | prob:  0.0
# word:  attention | prob_word:  0.0011376564277588168 | c_i:  1 | prob:  0.0
# word:  as | prob_word:  0.004550625711035267 | c_i:  9 | prob:  0.0
# word:  we | prob_word:  1e-06 | c_i:  4 | prob:  0.0
# word:  move | prob_word:  1e-06 | c_i:  1 | prob:  0.0
# word:  deeper | prob_word:  1e-06 | c_i:  1 | prob:  0.0
# word:  into | prob_word:  1e-06 | c_i:  3 | prob:  0.0
# word:  understanding | prob_word:  0.0022753128555176336 | c_i:  2 | prob:  0.0
# word:  current | prob_word:  0.004550625711035267 | c_i:  1 | prob:  0.0
# word:  is | prob_word:  0.009101251422070534 | c_i:  19 | prob:  0.0
# word:  more | prob_word:  0.004550625711035267 | c_i:  4 | prob:  0.0
# word:  important | prob_word:  1e-06 | c_i:  1 | prob:  0.0
# word:  than | prob_word:  1e-06 | c_i:  1 | prob:  0.0
# word:  ever | prob_word:  1e-06 | c_i:  1 | prob:  0.0
# word:  not | prob_word:  1e-06 | c_i:  1 | prob:  0.0
# word:  just | prob_word:  1e-06 | c_i:  1 | prob:  0.0
# word:  for | prob_word:  0.012514220705346985 | c_i:  11 | prob:  0.0
# word:  governments | prob_word:  0.0034129692832764505 | c_i:  3 | prob:  0.0
# word:  policymakers | prob_word:  1e-06 | c_i:  1 | prob:  0.0
# word:  but | prob_word:  0.0022753128555176336 | c_i:  9 | prob:  0.0
# word:  every | prob_word:  1e-06 | c_i:  2 | prob:  0.0
# word:  individual | prob_word:  1e-06 | c_i:  2 | prob:  0.0
# word:  who | prob_word:  1e-06 | c_i:  1 | prob:  0.0
# word:  seeks | prob_word:  1e-06 | c_i:  1 | prob:  0.0
# word:  navigate | prob_word:  0.0011376564277588168 | c_i:  1 | prob:  0.0
# word:  an | prob_word:  0.0011376564277588168 | c_i:  1 | prob:  0.0
# word:  increasingly | prob_word:  1e-06 | c_i:  1 | prob:  0.0
# word:  interconnected | prob_word:  1e-06 | c_i:  1 | prob:  0.0
# word:  upheavals | prob_word:  1e-06 | c_i:  1 | prob:  0.0
# word:  diplomatic | prob_word:  0.0022753128555176336 | c_i:  3 | prob:  0.0
# word:  maneuvers | prob_word:  1e-06 | c_i:  1 | prob:  0.0
# word:  conflict | prob_word:  0.0022753128555176336 | c_i:  3 | prob:  0.0
# word:  zones | prob_word:  1e-06 | c_i:  1 | prob:  0.0
# word:  russiaukraine | prob_word:  0.0022753128555176336 | c_i:  1 | prob:  0.0
# word:  war | prob_word:  0.004550625711035267 | c_i:  2 | prob:  0.0
# word:  persists | prob_word:  1e-06 | c_i:  1 | prob:  0.0
# word:  defining | prob_word:  0.0011376564277588168 | c_i:  1 | prob:  0.0
# word:  modern | prob_word:  1e-06 | c_i:  2 | prob:  0.0
# word:  era | prob_word:  1e-06 | c_i:  1 | prob:  0.0
# word:  with | prob_word:  0.013651877133105802 | c_i:  12 | prob:  0.0
# word:  no | prob_word:  1e-06 | c_i:  3 | prob:  0.0
# word:  clear | prob_word:  1e-06 | c_i:  1 | prob:  0.0
# word:  resolution | prob_word:  1e-06 | c_i:  1 | prob:  0.0
# word:  sight | prob_word:  1e-06 | c_i:  1 | prob:  0.0
# word:  ukraine | prob_word:  0.0022753128555176336 | c_i:  1 | prob:  0.0
# word:  backed | prob_word:  1e-06 | c_i:  1 | prob:  0.0
# word:  by | prob_word:  0.0022753128555176336 | c_i:  2 | prob:  0.0
# word:  western | prob_word:  0.0022753128555176336 | c_i:  1 | prob:  0.0
# word:  nations | prob_word:  0.0034129692832764505 | c_i:  3 | prob:  0.0
# word:  its | prob_word:  0.0011376564277588168 | c_i:  9 | prob:  0.0
# word:  struggle | prob_word:  1e-06 | c_i:  1 | prob:  0.0
# word:  sovereignty | prob_word:  0.0011376564277588168 | c_i:  1 | prob:  0.0
# word:  while | prob_word:  0.004550625711035267 | c_i:  7 | prob:  0.0
# word:  russia | prob_word:  0.0022753128555176336 | c_i:  1 | prob:  0.0
# word:  remains | prob_word:  0.004550625711035267 | c_i:  7 | prob:  0.0
# word:  determined | prob_word:  1e-06 | c_i:  1 | prob:  0.0
# word:  secure | prob_word:  1e-06 | c_i:  1 | prob:  0.0
# word:  strategic | prob_word:  1e-06 | c_i:  1 | prob:  0.0
# word:  interests | prob_word:  1e-06 | c_i:  1 | prob:  0.0
# word:  sanctions | prob_word:  0.0022753128555176336 | c_i:  1 | prob:  0.0
# word:  on | prob_word:  0.005688282138794084 | c_i:  7 | prob:  0.0
# word:  moscow | prob_word:  1e-06 | c_i:  1 | prob:  0.0
# word:  have | prob_word:  0.017064846416382253 | c_i:  6 | prob:  0.0
# word:  crippled | prob_word:  1e-06 | c_i:  1 | prob:  0.0
# word:  certain | prob_word:  1e-06 | c_i:  2 | prob:  0.0
# word:  sectors | prob_word:  1e-06 | c_i:  1 | prob:  0.0
# word:  economy | prob_word:  1e-06 | c_i:  3 | prob:  0.0
# word:  yet | prob_word:  0.0011376564277588168 | c_i:  2 | prob:  0.0
# word:  markets | prob_word:  0.0011376564277588168 | c_i:  3 | prob:  0.0
# word:  remain | prob_word:  0.0034129692832764505 | c_i:  7 | prob:  0.0
# word:  deeply | prob_word:  1e-06 | c_i:  1 | prob:  0.0
# word:  affected | prob_word:  1e-06 | c_i:  1 | prob:  0.0
# word:  energy | prob_word:  0.007963594994311717 | c_i:  4 | prob:  0.0
# word:  shortages | prob_word:  1e-06 | c_i:  1 | prob:  0.0
# word:  rippling | prob_word:  1e-06 | c_i:  1 | prob:  0.0
# word:  across | prob_word:  0.0011376564277588168 | c_i:  1 | prob:  0.0
# word:  continents | prob_word:  1e-06 | c_i:  1 | prob:  0.0
# word:  meanwhile | prob_word:  1e-06 | c_i:  3 | prob:  0.0
# word:  international | prob_word:  0.0011376564277588168 | c_i:  2 | prob:  0.0
# word:  channels | prob_word:  1e-06 | c_i:  1 | prob:  0.0
# word:  active | prob_word:  1e-06 | c_i:  1 | prob:  0.0
# word:  ceasefire | prob_word:  1e-06 | c_i:  1 | prob:  0.0
# word:  negotiations | prob_word:  0.0011376564277588168 | c_i:  1 | prob:  0.0
# word:  made | prob_word:  1e-06 | c_i:  1 | prob:  0.0
# word:  little | prob_word:  1e-06 | c_i:  1 | prob:  0.0
# word:  tangible | prob_word:  1e-06 | c_i:  1 | prob:  0.0
# word:  progress | prob_word:  0.0011376564277588168 | c_i:  2 | prob:  0.0
# word:  elsewhere | prob_word:  1e-06 | c_i:  1 | prob:  0.0
# word:  tensions | prob_word:  0.005688282138794084 | c_i:  2 | prob:  0.0
# word:  between | prob_word:  0.0022753128555176336 | c_i:  2 | prob:  0.0
# word:  china | prob_word:  1e-06 | c_i:  3 | prob:  0.0
# word:  taiwan | prob_word:  0.0011376564277588168 | c_i:  1 | prob:  0.0
# word:  escalated | prob_word:  1e-06 | c_i:  1 | prob:  0.0
# word:  drawing | prob_word:  1e-06 | c_i:  1 | prob:  0.0
# word:  united | prob_word:  0.0011376564277588168 | c_i:  3 | prob:  0.0
# word:  states | prob_word:  0.0011376564277588168 | c_i:  3 | prob:  0.0
# word:  allies | prob_word:  0.0011376564277588168 | c_i:  1 | prob:  0.0
# word:  precarious | prob_word:  1e-06 | c_i:  1 | prob:  0.0
# word:  game | prob_word:  1e-06 | c_i:  2 | prob:  0.0
# word:  military | prob_word:  0.004550625711035267 | c_i:  1 | prob:  0.0
# word:  posturing | prob_word:  1e-06 | c_i:  1 | prob:  0.0
# word:  flexes | prob_word:  1e-06 | c_i:  1 | prob:  0.0
# word:  naval | prob_word:  1e-06 | c_i:  1 | prob:  0.0
# word:  indopacific | prob_word:  0.0011376564277588168 | c_i:  2 | prob:  0.0
# word:  such | prob_word:  0.0022753128555176336 | c_i:  1 | prob:  0.0
# word:  japan | prob_word:  1e-06 | c_i:  1 | prob:  0.0
# word:  south | prob_word:  1e-06 | c_i:  1 | prob:  0.0
# word:  korea | prob_word:  1e-06 | c_i:  1 | prob:  0.0
# word:  bolster | prob_word:  1e-06 | c_i:  1 | prob:  0.0
# word:  their | prob_word:  0.0022753128555176336 | c_i:  4 | prob:  0.0
# word:  defenses | prob_word:  1e-06 | c_i:  1 | prob:  0.0
# word:  preparing | prob_word:  0.0011376564277588168 | c_i:  1 | prob:  0.0
# word:  potential | prob_word:  0.0022753128555176336 | c_i:  4 | prob:  0.0
# word:  question | prob_word:  1e-06 | c_i:  1 | prob:  0.0
# word:  will | prob_word:  0.0011376564277588168 | c_i:  4 | prob:  0.0
# word:  talks | prob_word:  1e-06 | c_i:  1 | prob:  0.0
# word:  diffuse | prob_word:  1e-06 | c_i:  1 | prob:  0.0
# word:  situation | prob_word:  0.0011376564277588168 | c_i:  1 | prob:  0.0
# word:  or | prob_word:  1e-06 | c_i:  2 | prob:  0.0
# word:  greater | prob_word:  1e-06 | c_i:  1 | prob:  0.0
# word:  confrontation | prob_word:  0.0011376564277588168 | c_i:  1 | prob:  0.0
# word:  inevitable | prob_word:  1e-06 | c_i:  1 | prob:  0.0
# word:  role | prob_word:  1e-06 | c_i:  2 | prob:  0.0
# word:  superpowers | prob_word:  1e-06 | c_i:  1 | prob:  0.0
# word:  stability | prob_word:  1e-06 | c_i:  1 | prob:  0.0
# word:  dominant | prob_word:  1e-06 | c_i:  1 | prob:  0.0
# word:  force | prob_word:  1e-06 | c_i:  1 | prob:  0.0
# word:  stage | prob_word:  1e-06 | c_i:  1 | prob:  0.0
# word:  grapples | prob_word:  1e-06 | c_i:  1 | prob:  0.0
# word:  both | prob_word:  0.0011376564277588168 | c_i:  1 | prob:  0.0
# word:  domestic | prob_word:  1e-06 | c_i:  1 | prob:  0.0
# word:  challenges | prob_word:  0.0034129692832764505 | c_i:  5 | prob:  0.0
# word:  washington | prob_word:  1e-06 | c_i:  1 | prob:  0.0
# word:  tightens | prob_word:  1e-06 | c_i:  1 | prob:  0.0
# word:  alliances | prob_word:  1e-06 | c_i:  1 | prob:  0.0
# word:  nato | prob_word:  1e-06 | c_i:  1 | prob:  0.0
# word:  partners | prob_word:  1e-06 | c_i:  1 | prob:  0.0
# word:  rivalry | prob_word:  1e-06 | c_i:  1 | prob:  0.0
# word:  beijing | prob_word:  1e-06 | c_i:  2 | prob:  0.0
# word:  grows | prob_word:  1e-06 | c_i:  1 | prob:  0.0
# word:  intense | prob_word:  0.0011376564277588168 | c_i:  3 | prob:  0.0
# word:  trade | prob_word:  0.0011376564277588168 | c_i:  1 | prob:  0.0
# word:  wars | prob_word:  1e-06 | c_i:  1 | prob:  0.0
# word:  espionage | prob_word:  1e-06 | c_i:  1 | prob:  0.0
# word:  accusations | prob_word:  1e-06 | c_i:  1 | prob:  0.0
# word:  battle | prob_word:  1e-06 | c_i:  1 | prob:  0.0
# word:  supremacy | prob_word:  1e-06 | c_i:  1 | prob:  0.0
# word:  define | prob_word:  1e-06 | c_i:  1 | prob:  0.0
# word:  this | prob_word:  0.0011376564277588168 | c_i:  3 | prob:  0.0
# word:  cold | prob_word:  1e-06 | c_i:  1 | prob:  0.0
# word:  europes | prob_word:  1e-06 | c_i:  1 | prob:  0.0
# word:  position | prob_word:  1e-06 | c_i:  1 | prob:  0.0
# word:  bloc | prob_word:  1e-06 | c_i:  1 | prob:  0.0
# word:  somewhat | prob_word:  1e-06 | c_i:  1 | prob:  0.0
# word:  uncertain | prob_word:  1e-06 | c_i:  1 | prob:  0.0
# word:  internal | prob_word:  1e-06 | c_i:  1 | prob:  0.0
# word:  divisions | prob_word:  1e-06 | c_i:  1 | prob:  0.0
# word:  over | prob_word:  1e-06 | c_i:  2 | prob:  0.0
# word:  policies | prob_word:  0.0011376564277588168 | c_i:  3 | prob:  0.0
# word:  defense | prob_word:  1e-06 | c_i:  1 | prob:  0.0
# word:  strategies | prob_word:  1e-06 | c_i:  1 | prob:  0.0
# word:  pressures | prob_word:  1e-06 | c_i:  1 | prob:  0.0
# word:  market | prob_word:  0.0034129692832764505 | c_i:  1 | prob:  0.0
# word:  volatility | prob_word:  0.0011376564277588168 | c_i:  1 | prob:  0.0
# word:  inflation | prob_word:  0.0034129692832764505 | c_i:  3 | prob:  0.0
# word:  interest | prob_word:  0.0011376564277588168 | c_i:  2 | prob:  0.0
# word:  rates | prob_word:  1e-06 | c_i:  3 | prob:  0.0
# word:  recession | prob_word:  1e-06 | c_i:  1 | prob:  0.0
# word:  risks | prob_word:  1e-06 | c_i:  1 | prob:  0.0
# word:  recovery | prob_word:  0.0022753128555176336 | c_i:  1 | prob:  0.0
# word:  from | prob_word:  0.0034129692832764505 | c_i:  4 | prob:  0.0
# word:  past | prob_word:  0.0011376564277588168 | c_i:  1 | prob:  0.0
# word:  disruptions | prob_word:  0.0011376564277588168 | c_i:  2 | prob:  0.0
# word:  has | prob_word:  0.010238907849829351 | c_i:  5 | prob:  0.0
# word:  been | prob_word:  0.0011376564277588168 | c_i:  2 | prob:  0.0
# word:  uneven | prob_word:  1e-06 | c_i:  1 | prob:  0.0
# word:  continuing | prob_word:  1e-06 | c_i:  1 | prob:  0.0
# word:  plague | prob_word:  1e-06 | c_i:  1 | prob:  0.0
# word:  european | prob_word:  0.0011376564277588168 | c_i:  1 | prob:  0.0
# word:  union | prob_word:  1e-06 | c_i:  1 | prob:  0.0
# word:  aggressive | prob_word:  0.0011376564277588168 | c_i:  1 | prob:  0.0
# word:  raising | prob_word:  0.0011376564277588168 | c_i:  2 | prob:  0.0
# word:  curb | prob_word:  0.0011376564277588168 | c_i:  1 | prob:  0.0
# word:  led | prob_word:  0.0011376564277588168 | c_i:  1 | prob:  0.0
# word:  fears | prob_word:  1e-06 | c_i:  1 | prob:  0.0
# word:  slowdowns | prob_word:  1e-06 | c_i:  1 | prob:  0.0
# word:  consumers | prob_word:  1e-06 | c_i:  1 | prob:  0.0
# word:  face | prob_word:  1e-06 | c_i:  2 | prob:  0.0
# word:  rising | prob_word:  0.0022753128555176336 | c_i:  1 | prob:  0.0
# word:  costs | prob_word:  0.0011376564277588168 | c_i:  1 | prob:  0.0
# word:  everyday | prob_word:  1e-06 | c_i:  2 | prob:  0.0
# word:  goods | prob_word:  1e-06 | c_i:  1 | prob:  0.0
# word:  groceries | prob_word:  1e-06 | c_i:  1 | prob:  0.0
# word:  fuel | prob_word:  1e-06 | c_i:  2 | prob:  0.0
# word:  forcing | prob_word:  1e-06 | c_i:  2 | prob:  0.0
# word:  implement | prob_word:  1e-06 | c_i:  2 | prob:  0.0
# word:  relief | prob_word:  1e-06 | c_i:  1 | prob:  0.0
# word:  measures | prob_word:  0.0011376564277588168 | c_i:  1 | prob:  0.0
# word:  where | prob_word:  0.0011376564277588168 | c_i:  1 | prob:  0.0
# word:  possible | prob_word:  1e-06 | c_i:  2 | prob:  0.0
# word:  asia | prob_word:  1e-06 | c_i:  1 | prob:  0.0
# word:  chinas | prob_word:  0.0022753128555176336 | c_i:  1 | prob:  0.0
# word:  experiencing | prob_word:  0.0011376564277588168 | c_i:  2 | prob:  0.0
# word:  downturn | prob_word:  1e-06 | c_i:  1 | prob:  0.0
# word:  manufacturing | prob_word:  0.0011376564277588168 | c_i:  1 | prob:  0.0
# word:  foreign | prob_word:  1e-06 | c_i:  1 | prob:  0.0
# word:  investment | prob_word:  1e-06 | c_i:  1 | prob:  0.0
# word:  slows | prob_word:  1e-06 | c_i:  1 | prob:  0.0
# word:  once | prob_word:  1e-06 | c_i:  1 | prob:  0.0
# word:  considered | prob_word:  1e-06 | c_i:  1 | prob:  0.0
# word:  engine | prob_word:  1e-06 | c_i:  1 | prob:  0.0
# word:  growth | prob_word:  1e-06 | c_i:  1 | prob:  0.0
# word:  now | prob_word:  1e-06 | c_i:  2 | prob:  0.0
# word:  faces | prob_word:  1e-06 | c_i:  1 | prob:  0.0
# word:  maintaining | prob_word:  1e-06 | c_i:  1 | prob:  0.0
# word:  momentum | prob_word:  0.0022753128555176336 | c_i:  2 | prob:  0.0
# word:  chinese | prob_word:  1e-06 | c_i:  1 | prob:  0.0
# word:  government | prob_word:  0.0011376564277588168 | c_i:  1 | prob:  0.0
# word:  implementing | prob_word:  1e-06 | c_i:  1 | prob:  0.0
# word:  stabilize | prob_word:  0.0011376564277588168 | c_i:  1 | prob:  0.0
# word:  questions | prob_word:  1e-06 | c_i:  3 | prob:  0.0
# word:  about | prob_word:  0.0034129692832764505 | c_i:  4 | prob:  0.0
# word:  longterm | prob_word:  0.0011376564277588168 | c_i:  1 | prob:  0.0
# word:  sustainability | prob_word:  1e-06 | c_i:  1 | prob:  0.0
# word:  cryptocurrencys | prob_word:  1e-06 | c_i:  1 | prob:  0.0
# word:  rise | prob_word:  0.0022753128555176336 | c_i:  3 | prob:  0.0
# word:  fall | prob_word:  1e-06 | c_i:  1 | prob:  0.0
# word:  unpredictable | prob_word:  1e-06 | c_i:  1 | prob:  0.0
# word:  cryptocurrency | prob_word:  0.0022753128555176336 | c_i:  1 | prob:  0.0
# word:  hot | prob_word:  1e-06 | c_i:  1 | prob:  0.0
# word:  topic | prob_word:  1e-06 | c_i:  2 | prob:  0.0
# word:  digital | prob_word:  0.0022753128555176336 | c_i:  3 | prob:  0.0
# word:  assets | prob_word:  0.0011376564277588168 | c_i:  1 | prob:  0.0
# word:  sharp | prob_word:  1e-06 | c_i:  1 | prob:  0.0
# word:  fluctuations | prob_word:  0.0011376564277588168 | c_i:  1 | prob:  0.0
# word:  value | prob_word:  1e-06 | c_i:  1 | prob:  0.0
# word:  regulatory | prob_word:  0.0022753128555176336 | c_i:  1 | prob:  0.0
# word:  crackdowns | prob_word:  0.0011376564277588168 | c_i:  1 | prob:  0.0
# word:  multiple | prob_word:  1e-06 | c_i:  1 | prob:  0.0
# word:  countries | prob_word:  0.0022753128555176336 | c_i:  2 | prob:  0.0
# word:  dampened | prob_word:  1e-06 | c_i:  1 | prob:  0.0
# word:  enthusiasm | prob_word:  1e-06 | c_i:  1 | prob:  0.0
# word:  many | prob_word:  0.0011376564277588168 | c_i:  1 | prob:  0.0
# word:  believe | prob_word:  1e-06 | c_i:  1 | prob:  0.0
# word:  blockchain | prob_word:  1e-06 | c_i:  1 | prob:  0.0
# word:  technology | prob_word:  0.0011376564277588168 | c_i:  3 | prob:  0.0
# word:  revolutionize | prob_word:  1e-06 | c_i:  1 | prob:  0.0
# word:  finance | prob_word:  0.0011376564277588168 | c_i:  1 | prob:  0.0
# word:  bitcoin | prob_word:  0.0011376564277588168 | c_i:  1 | prob:  0.0
# word:  ethereum | prob_word:  1e-06 | c_i:  1 | prob:  0.0
# word:  other | prob_word:  0.0011376564277588168 | c_i:  2 | prob:  0.0
# word:  major | prob_word:  0.004550625711035267 | c_i:  1 | prob:  0.0
# word:  cryptocurrencies | prob_word:  1e-06 | c_i:  1 | prob:  0.0
# word:  continue | prob_word:  0.0034129692832764505 | c_i:  4 | prob:  0.0
# word:  scrutiny | prob_word:  1e-06 | c_i:  1 | prob:  0.0
# word:  institutional | prob_word:  1e-06 | c_i:  1 | prob:  0.0
# word:  investors | prob_word:  1e-06 | c_i:  1 | prob:  0.0
# word:  are | prob_word:  0.006825938566552901 | c_i:  13 | prob:  0.0
# word:  cautiously | prob_word:  1e-06 | c_i:  1 | prob:  0.0
# word:  exploring | prob_word:  0.0011376564277588168 | c_i:  1 | prob:  0.0
# word:  integration | prob_word:  1e-06 | c_i:  1 | prob:  0.0
# word:  mainstream | prob_word:  1e-06 | c_i:  1 | prob:  0.0
# word:  financial | prob_word:  0.0034129692832764505 | c_i:  1 | prob:  0.0
# word:  systems | prob_word:  1e-06 | c_i:  2 | prob:  0.0
# word:  future | prob_word:  0.0011376564277588168 | c_i:  4 | prob:  0.0
# word:  innovation | prob_word:  0.0011376564277588168 | c_i:  3 | prob:  0.0
# word:  artificial | prob_word:  0.0011376564277588168 | c_i:  1 | prob:  0.0
# word:  intelligence | prob_word:  0.0011376564277588168 | c_i:  1 | prob:  0.0
# word:  changer | prob_word:  1e-06 | c_i:  1 | prob:  0.0
# word:  ai | prob_word:  0.0022753128555176336 | c_i:  1 | prob:  0.0
# word:  longer | prob_word:  1e-06 | c_i:  2 | prob:  0.0
# word:  futuristic | prob_word:  1e-06 | c_i:  1 | prob:  0.0
# word:  conceptit | prob_word:  1e-06 | c_i:  1 | prob:  0.0
# word:  here | prob_word:  1e-06 | c_i:  1 | prob:  0.0
# word:  it | prob_word:  0.0011376564277588168 | c_i:  2 | prob:  0.0
# word:  transforming | prob_word:  0.0011376564277588168 | c_i:  1 | prob:  0.0
# word:  industry | prob_word:  1e-06 | c_i:  2 | prob:  0.0
# word:  imaginable | prob_word:  1e-06 | c_i:  1 | prob:  0.0
# word:  businesses | prob_word:  0.0011376564277588168 | c_i:  1 | prob:  0.0
# word:  leveraging | prob_word:  1e-06 | c_i:  1 | prob:  0.0
# word:  aidriven | prob_word:  0.0011376564277588168 | c_i:  1 | prob:  0.0
# word:  automation | prob_word:  0.0022753128555176336 | c_i:  1 | prob:  0.0
# word:  enhance | prob_word:  1e-06 | c_i:  1 | prob:  0.0
# word:  productivity | prob_word:  1e-06 | c_i:  1 | prob:  0.0
# word:  aigenerated | prob_word:  1e-06 | c_i:  1 | prob:  0.0
# word:  content | prob_word:  0.0011376564277588168 | c_i:  1 | prob:  0.0
# word:  revolutionizing | prob_word:  1e-06 | c_i:  1 | prob:  0.0
# word:  media | prob_word:  1e-06 | c_i:  1 | prob:  0.0
# word:  entertainment | prob_word:  1e-06 | c_i:  1 | prob:  0.0
# word:  customer | prob_word:  0.0011376564277588168 | c_i:  1 | prob:  0.0
# word:  service | prob_word:  0.0011376564277588168 | c_i:  1 | prob:  0.0
# word:  however | prob_word:  0.0034129692832764505 | c_i:  3 | prob:  0.0
# word:  job | prob_word:  0.0011376564277588168 | c_i:  2 | prob:  0.0
# word:  displacement | prob_word:  0.0011376564277588168 | c_i:  1 | prob:  0.0
# word:  ethical | prob_word:  1e-06 | c_i:  2 | prob:  0.0
# word:  dilemmas | prob_word:  1e-06 | c_i:  1 | prob:  0.0
# word:  at | prob_word:  1e-06 | c_i:  3 | prob:  0.0
# word:  forefront | prob_word:  1e-06 | c_i:  1 | prob:  0.0
# word:  discussions | prob_word:  1e-06 | c_i:  1 | prob:  0.0
# word:  scrambling | prob_word:  1e-06 | c_i:  1 | prob:  0.0
# word:  regulations | prob_word:  0.0011376564277588168 | c_i:  1 | prob:  0.0
# word:  aiming | prob_word:  1e-06 | c_i:  1 | prob:  0.0
# word:  balance | prob_word:  1e-06 | c_i:  1 | prob:  0.0
# word:  security | prob_word:  0.0011376564277588168 | c_i:  2 | prob:  0.0
# word:  space | prob_word:  0.005688282138794084 | c_i:  6 | prob:  0.0
# word:  exploration | prob_word:  0.0022753128555176336 | c_i:  2 | prob:  0.0
# word:  new | prob_word:  0.0034129692832764505 | c_i:  5 | prob:  0.0
# word:  race | prob_word:  1e-06 | c_i:  1 | prob:  0.0
# word:  humanitys | prob_word:  1e-06 | c_i:  1 | prob:  0.0
# word:  ambitions | prob_word:  0.0011376564277588168 | c_i:  1 | prob:  0.0
# word:  reaching | prob_word:  1e-06 | c_i:  1 | prob:  0.0
# word:  heights | prob_word:  1e-06 | c_i:  1 | prob:  0.0
# word:  artemis | prob_word:  0.0011376564277588168 | c_i:  1 | prob:  0.0
# word:  program | prob_word:  0.0011376564277588168 | c_i:  2 | prob:  0.0
# word:  track | prob_word:  1e-06 | c_i:  1 | prob:  0.0
# word:  return | prob_word:  0.0011376564277588168 | c_i:  1 | prob:  0.0
# word:  humans | prob_word:  0.0011376564277588168 | c_i:  1 | prob:  0.0
# word:  moon | prob_word:  0.0011376564277588168 | c_i:  1 | prob:  0.0
# word:  spacex | prob_word:  0.0011376564277588168 | c_i:  1 | prob:  0.0
# word:  private | prob_word:  0.0011376564277588168 | c_i:  1 | prob:  0.0
# word:  companies | prob_word:  0.0011376564277588168 | c_i:  1 | prob:  0.0
# word:  push | prob_word:  0.0011376564277588168 | c_i:  1 | prob:  0.0
# word:  boundaries | prob_word:  1e-06 | c_i:  2 | prob:  0.0
# word:  commercial | prob_word:  0.0011376564277588168 | c_i:  1 | prob:  0.0
# word:  travel | prob_word:  0.0011376564277588168 | c_i:  1 | prob:  0.0
# word:  too | prob_word:  1e-06 | c_i:  1 | prob:  0.0
# word:  intensified | prob_word:  0.0022753128555176336 | c_i:  1 | prob:  0.0
# word:  plans | prob_word:  1e-06 | c_i:  1 | prob:  0.0
# word:  mars | prob_word:  0.0011376564277588168 | c_i:  1 | prob:  0.0
# word:  expanded | prob_word:  1e-06 | c_i:  1 | prob:  0.0
# word:  lunar | prob_word:  1e-06 | c_i:  1 | prob:  0.0
# word:  missions | prob_word:  0.0011376564277588168 | c_i:  1 | prob:  0.0
# word:  advances | prob_word:  1e-06 | c_i:  2 | prob:  0.0
# word:  arise | prob_word:  1e-06 | c_i:  1 | prob:  0.0
# word:  colonization | prob_word:  0.0011376564277588168 | c_i:  1 | prob:  0.0
# word:  governance | prob_word:  1e-06 | c_i:  1 | prob:  0.0
# word:  extraterrestrial | prob_word:  1e-06 | c_i:  1 | prob:  0.0
# word:  resources | prob_word:  1e-06 | c_i:  1 | prob:  0.0
# word:  climate | prob_word:  0.004550625711035267 | c_i:  4 | prob:  0.0
# word:  action | prob_word:  0.0011376564277588168 | c_i:  3 | prob:  0.0
# word:  warming | prob_word:  1e-06 | c_i:  1 | prob:  0.0
# word:  extreme | prob_word:  0.0022753128555176336 | c_i:  1 | prob:  0.0
# word:  weather | prob_word:  0.0022753128555176336 | c_i:  1 | prob:  0.0
# word:  effects | prob_word:  1e-06 | c_i:  1 | prob:  0.0
# word:  change | prob_word:  0.0022753128555176336 | c_i:  2 | prob:  0.0
# word:  distant | prob_word:  1e-06 | c_i:  1 | prob:  0.0
# word:  threatsthey | prob_word:  1e-06 | c_i:  1 | prob:  0.0
# word:  happening | prob_word:  1e-06 | c_i:  1 | prob:  0.0
# word:  wildfires | prob_word:  0.0011376564277588168 | c_i:  1 | prob:  0.0
# word:  hurricanes | prob_word:  0.0011376564277588168 | c_i:  1 | prob:  0.0
# word:  heatwaves | prob_word:  0.0011376564277588168 | c_i:  1 | prob:  0.0
# word:  becoming | prob_word:  0.0011376564277588168 | c_i:  2 | prob:  0.0
# word:  frequent | prob_word:  0.0022753128555176336 | c_i:  1 | prob:  0.0
# word:  reevaluate | prob_word:  1e-06 | c_i:  1 | prob:  0.0
# word:  latest | prob_word:  1e-06 | c_i:  1 | prob:  0.0
# word:  summits | prob_word:  1e-06 | c_i:  1 | prob:  0.0
# word:  seen | prob_word:  1e-06 | c_i:  1 | prob:  0.0
# word:  renewed | prob_word:  1e-06 | c_i:  1 | prob:  0.0
# word:  commitments | prob_word:  1e-06 | c_i:  1 | prob:  0.0
# word:  carbon | prob_word:  0.0011376564277588168 | c_i:  1 | prob:  0.0
# word:  neutrality | prob_word:  1e-06 | c_i:  1 | prob:  0.0
# word:  gap | prob_word:  1e-06 | c_i:  1 | prob:  0.0
# word:  promises | prob_word:  1e-06 | c_i:  1 | prob:  0.0
# word:  wide | prob_word:  1e-06 | c_i:  1 | prob:  0.0
# word:  renewable | prob_word:  0.0022753128555176336 | c_i:  2 | prob:  0.0
# word:  vs | prob_word:  1e-06 | c_i:  1 | prob:  0.0
# word:  fossil | prob_word:  0.0011376564277588168 | c_i:  2 | prob:  0.0
# word:  fuels | prob_word:  0.0011376564277588168 | c_i:  1 | prob:  0.0
# word:  transition | prob_word:  0.0011376564277588168 | c_i:  1 | prob:  0.0
# word:  accelerating | prob_word:  1e-06 | c_i:  1 | prob:  0.0
# word:  wield | prob_word:  1e-06 | c_i:  1 | prob:  0.0
# word:  significant | prob_word:  0.005688282138794084 | c_i:  1 | prob:  0.0
# word:  influence | prob_word:  1e-06 | c_i:  2 | prob:  0.0
# word:  solar | prob_word:  1e-06 | c_i:  1 | prob:  0.0
# word:  wind | prob_word:  1e-06 | c_i:  1 | prob:  0.0
# word:  installations | prob_word:  1e-06 | c_i:  1 | prob:  0.0
# word:  worlds | prob_word:  1e-06 | c_i:  1 | prob:  0.0
# word:  heavily | prob_word:  1e-06 | c_i:  1 | prob:  0.0
# word:  reliant | prob_word:  1e-06 | c_i:  1 | prob:  0.0
# word:  oil | prob_word:  1e-06 | c_i:  1 | prob:  0.0
# word:  gas | prob_word:  1e-06 | c_i:  1 | prob:  0.0
# word:  debate | prob_word:  1e-06 | c_i:  2 | prob:  0.0
# word:  nuclear | prob_word:  0.0022753128555176336 | c_i:  2 | prob:  0.0
# word:  energys | prob_word:  1e-06 | c_i:  1 | prob:  0.0
# word:  sustainable | prob_word:  0.0011376564277588168 | c_i:  1 | prob:  0.0
# word:  also | prob_word:  0.0034129692832764505 | c_i:  3 | prob:  0.0
# word:  heating | prob_word:  1e-06 | c_i:  1 | prob:  0.0
# word:  up | prob_word:  1e-06 | c_i:  1 | prob:  0.0
# word:  some | prob_word:  0.0022753128555176336 | c_i:  2 | prob:  0.0
# word:  expanding | prob_word:  1e-06 | c_i:  1 | prob:  0.0
# word:  programs | prob_word:  1e-06 | c_i:  1 | prob:  0.0
# word:  others | prob_word:  1e-06 | c_i:  1 | prob:  0.0
# word:  hesitant | prob_word:  1e-06 | c_i:  1 | prob:  0.0
# word:  due | prob_word:  0.0022753128555176336 | c_i:  1 | prob:  0.0
# word:  safety | prob_word:  1e-06 | c_i:  1 | prob:  0.0
# word:  social | prob_word:  0.006825938566552901 | c_i:  4 | prob:  0.0
# word:  transformations | prob_word:  1e-06 | c_i:  1 | prob:  0.0
# word:  cultural | prob_word:  1e-06 | c_i:  1 | prob:  0.0
# word:  revolution | prob_word:  0.0011376564277588168 | c_i:  1 | prob:  0.0
# word:  life | prob_word:  1e-06 | c_i:  1 | prob:  0.0
# word:  remote | prob_word:  1e-06 | c_i:  1 | prob:  0.0
# word:  work | prob_word:  1e-06 | c_i:  2 | prob:  0.0
# word:  banking | prob_word:  1e-06 | c_i:  1 | prob:  0.0
# word:  reshape | prob_word:  1e-06 | c_i:  1 | prob:  0.0
# word:  how | prob_word:  1e-06 | c_i:  2 | prob:  0.0
# word:  live | prob_word:  1e-06 | c_i:  1 | prob:  0.0
# word:  gig | prob_word:  1e-06 | c_i:  1 | prob:  0.0
# word:  creating | prob_word:  1e-06 | c_i:  1 | prob:  0.0
# word:  opportunities | prob_word:  1e-06 | c_i:  2 | prob:  0.0
# word:  labor | prob_word:  1e-06 | c_i:  1 | prob:  0.0
# word:  rights | prob_word:  0.004550625711035267 | c_i:  4 | prob:  0.0
# word:  medias | prob_word:  1e-06 | c_i:  1 | prob:  0.0
# word:  politics | prob_word:  0.0022753128555176336 | c_i:  1 | prob:  0.0
# word:  public | prob_word:  0.0022753128555176336 | c_i:  1 | prob:  0.0
# word:  opinion | prob_word:  1e-06 | c_i:  1 | prob:  0.0
# word:  strong | prob_word:  1e-06 | c_i:  1 | prob:  0.0
# word:  misinformation | prob_word:  0.0011376564277588168 | c_i:  1 | prob:  0.0
# word:  campaigns | prob_word:  0.0011376564277588168 | c_i:  1 | prob:  0.0
# word:  posing | prob_word:  1e-06 | c_i:  1 | prob:  0.0
# word:  persistent | prob_word:  1e-06 | c_i:  1 | prob:  0.0
# word:  challenge | prob_word:  0.0011376564277588168 | c_i:  1 | prob:  0.0
# word:  human | prob_word:  0.0022753128555176336 | c_i:  3 | prob:  0.0
# word:  justice | prob_word:  0.0011376564277588168 | c_i:  1 | prob:  0.0
# word:  movements | prob_word:  0.0022753128555176336 | c_i:  2 | prob:  0.0
# word:  globally | prob_word:  0.0011376564277588168 | c_i:  1 | prob:  0.0
# word:  advocating | prob_word:  0.0011376564277588168 | c_i:  1 | prob:  0.0
# word:  racial | prob_word:  0.0011376564277588168 | c_i:  1 | prob:  0.0
# word:  equality | prob_word:  0.0011376564277588168 | c_i:  1 | prob:  0.0
# word:  gender | prob_word:  0.0011376564277588168 | c_i:  1 | prob:  0.0
# word:  freedom | prob_word:  1e-06 | c_i:  2 | prob:  0.0
# word:  speech | prob_word:  1e-06 | c_i:  1 | prob:  0.0
# word:  gain | prob_word:  1e-06 | c_i:  1 | prob:  0.0
# word:  regions | prob_word:  0.0011376564277588168 | c_i:  1 | prob:  0.0
# word:  authoritarian | prob_word:  1e-06 | c_i:  1 | prob:  0.0
# word:  regimes | prob_word:  1e-06 | c_i:  1 | prob:  0.0
# word:  cracking | prob_word:  1e-06 | c_i:  1 | prob:  0.0
# word:  down | prob_word:  1e-06 | c_i:  1 | prob:  0.0
# word:  dissent | prob_word:  1e-06 | c_i:  1 | prob:  0.0
# word:  limiting | prob_word:  1e-06 | c_i:  1 | prob:  0.0
# word:  press | prob_word:  1e-06 | c_i:  1 | prob:  0.0
# word:  suppressing | prob_word:  1e-06 | c_i:  1 | prob:  0.0
# word:  activism | prob_word:  1e-06 | c_i:  1 | prob:  0.0
# word:  fight | prob_word:  1e-06 | c_i:  1 | prob:  0.0
# word:  democracy | prob_word:  1e-06 | c_i:  1 | prob:  0.0
# word:  critical | prob_word:  1e-06 | c_i:  1 | prob:  0.0
# word:  issue | prob_word:  0.0011376564277588168 | c_i:  1 | prob:  0.0
# word:  worldwide | prob_word:  0.0034129692832764505 | c_i:  2 | prob:  0.0
# word:  health | prob_word:  0.004550625711035267 | c_i:  4 | prob:  0.0
# word:  scientific | prob_word:  1e-06 | c_i:  1 | prob:  0.0
# word:  postpandemic | prob_word:  0.0011376564277588168 | c_i:  1 | prob:  0.0
# word:  covid | prob_word:  0.0011376564277588168 | c_i:  1 | prob:  0.0
# word:  pandemic | prob_word:  0.0011376564277588168 | c_i:  1 | prob:  0.0
# word:  largely | prob_word:  0.0011376564277588168 | c_i:  1 | prob:  0.0
# word:  subsided | prob_word:  0.0011376564277588168 | c_i:  1 | prob:  0.0
# word:  emerging | prob_word:  1e-06 | c_i:  1 | prob:  0.0
# word:  scientists | prob_word:  1e-06 | c_i:  1 | prob:  0.0
# word:  closely | prob_word:  1e-06 | c_i:  1 | prob:  0.0
# word:  monitoring | prob_word:  1e-06 | c_i:  1 | prob:  0.0
# word:  virus | prob_word:  1e-06 | c_i:  1 | prob:  0.0
# word:  outbreaks | prob_word:  1e-06 | c_i:  1 | prob:  0.0
# word:  mental | prob_word:  0.0022753128555176336 | c_i:  1 | prob:  0.0
# word:  awareness | prob_word:  0.0011376564277588168 | c_i:  1 | prob:  0.0
# word:  become | prob_word:  1e-06 | c_i:  1 | prob:  0.0
# word:  growing | prob_word:  1e-06 | c_i:  1 | prob:  0.0
# word:  concern | prob_word:  0.0011376564277588168 | c_i:  1 | prob:  0.0
# word:  healthcare | prob_word:  0.0022753128555176336 | c_i:  1 | prob:  0.0
# word:  under | prob_word:  1e-06 | c_i:  1 | prob:  0.0
# word:  pressure | prob_word:  1e-06 | c_i:  1 | prob:  0.0
# word:  modernize | prob_word:  1e-06 | c_i:  1 | prob:  0.0
# word:  prepare | prob_word:  1e-06 | c_i:  1 | prob:  0.0
# word:  crises | prob_word:  1e-06 | c_i:  1 | prob:  0.0
# word:  medical | prob_word:  1e-06 | c_i:  1 | prob:  0.0
# word:  innovations | prob_word:  0.0011376564277588168 | c_i:  1 | prob:  0.0
# word:  biotechnology | prob_word:  1e-06 | c_i:  2 | prob:  0.0
# word:  cancer | prob_word:  1e-06 | c_i:  1 | prob:  0.0
# word:  treatments | prob_word:  1e-06 | c_i:  2 | prob:  0.0
# word:  gene | prob_word:  1e-06 | c_i:  2 | prob:  0.0
# word:  editing | prob_word:  1e-06 | c_i:  1 | prob:  0.0
# word:  pushing | prob_word:  0.0011376564277588168 | c_i:  1 | prob:  0.0
# word:  what | prob_word:  1e-06 | c_i:  2 | prob:  0.0
# word:  medically | prob_word:  1e-06 | c_i:  1 | prob:  0.0
# word:  personalized | prob_word:  1e-06 | c_i:  1 | prob:  0.0
# word:  medicine | prob_word:  1e-06 | c_i:  1 | prob:  0.0
# word:  accessible | prob_word:  0.0011376564277588168 | c_i:  1 | prob:  0.0
# word:  offering | prob_word:  1e-06 | c_i:  1 | prob:  0.0
# word:  targeted | prob_word:  1e-06 | c_i:  1 | prob:  0.0
# word:  tailored | prob_word:  1e-06 | c_i:  1 | prob:  0.0
# word:  genetic | prob_word:  1e-06 | c_i:  1 | prob:  0.0
# word:  profiles | prob_word:  1e-06 | c_i:  1 | prob:  0.0
# word:  surrounding | prob_word:  1e-06 | c_i:  1 | prob:  0.0
# word:  modification | prob_word:  1e-06 | c_i:  1 | prob:  0.0
# word:  conclusion | prob_word:  0.0011376564277588168 | c_i:  1 | prob:  0.0
# word:  path | prob_word:  1e-06 | c_i:  1 | prob:  0.0
# word:  ahead | prob_word:  1e-06 | c_i:  2 | prob:  0.0
# word:  crossroads | prob_word:  1e-06 | c_i:  1 | prob:  0.0
# word:  facing | prob_word:  1e-06 | c_i:  1 | prob:  0.0
# word:  unprecedented | prob_word:  1e-06 | c_i:  1 | prob:  0.0
# word:  immense | prob_word:  1e-06 | c_i:  1 | prob:  0.0
# word:  geopolitical | prob_word:  0.004550625711035267 | c_i:  1 | prob:  0.0
# word:  uncertainties | prob_word:  0.0011376564277588168 | c_i:  1 | prob:  0.0
# word:  advancements | prob_word:  0.0034129692832764505 | c_i:  1 | prob:  0.0
# word:  reshaping | prob_word:  0.0011376564277588168 | c_i:  1 | prob:  0.0
# word:  society | prob_word:  1e-06 | c_i:  1 | prob:  0.0
# word:  look | prob_word:  1e-06 | c_i:  1 | prob:  0.0
# word:  adaptability | prob_word:  1e-06 | c_i:  1 | prob:  0.0
# word:  informed | prob_word:  0.0011376564277588168 | c_i:  2 | prob:  0.0
# word:  decisionmaking | prob_word:  1e-06 | c_i:  1 | prob:  0.0
# word:  be | prob_word:  0.0034129692832764505 | c_i:  2 | prob:  0.0
# word:  crucial | prob_word:  0.0011376564277588168 | c_i:  1 | prob:  0.0
# word:  navigating | prob_word:  1e-06 | c_i:  1 | prob:  0.0
# word:  whether | prob_word:  1e-06 | c_i:  1 | prob:  0.0
# word:  through | prob_word:  1e-06 | c_i:  1 | prob:  0.0
# word:  diplomacy | prob_word:  1e-06 | c_i:  1 | prob:  0.0
# word:  collective | prob_word:  1e-06 | c_i:  1 | prob:  0.0
# word:  defined | prob_word:  1e-06 | c_i:  1 | prob:  0.0
# word:  respond | prob_word:  1e-06 | c_i:  1 | prob:  0.0
# word:  todays | prob_word:  1e-06 | c_i:  1 | prob:  0.0
# word:  pressing | prob_word:  0.0011376564277588168 | c_i:  1 | prob:  0.0
# word:  issues | prob_word:  0.0034129692832764505 | c_i:  1 | prob:  0.0
# word:  one | prob_word:  1e-06 | c_i:  1 | prob:  0.0
# word:  thing | prob_word:  1e-06 | c_i:  1 | prob:  0.0
# word:  staying | prob_word:  0.0022753128555176336 | c_i:  1 | prob:  0.0
# word:  key | prob_word:  0.0011376564277588168 | c_i:  1 | prob:  0.0
# word:  comes | prob_word:  1e-06 | c_i:  1 | prob:  0.0
# word:  next | prob_word:  1e-06 | c_i:  1 | prob:  0.0
# ------------------------------
# word:  everchanging | prob_word:  1e-06 | c_i:  2 | prob:  1e-12
# word:  landscape | prob_word:  0.0015037593984962407 | c_i:  2 | prob:  2.2612923285657756e-18
# word:  global | prob_word:  0.010526315789473684 | c_i:  8 | prob:  3.408535857377741e-34
# word:  affairs | prob_word:  0.0030075187969924814 | c_i:  2 | prob:  3.0830783943718614e-39
# word:   | prob_word:  0.041353383458646614 | c_i:  43 | prob:  9.976073827793438e-99
# word:  in | prob_word:  0.02330827067669173 | c_i:  19 | prob:  9.586292119458619e-130
# word:  a | prob_word:  0.009774436090225564 | c_i:  18 | prob:  6.357720963321969e-166
# word:  world | prob_word:  0.0030075187969924814 | c_i:  6 | prob:  4.704912654042209e-181
# word:  that | prob_word:  1e-06 | c_i:  2 | prob:  4.704912654042209e-193
# word:  never | prob_word:  1e-06 | c_i:  1 | prob:  4.704912654042209e-199
# word:  stands | prob_word:  1e-06 | c_i:  1 | prob:  4.704912654042209e-205
# word:  still | prob_word:  1e-06 | c_i:  3 | prob:  4.7049126540422085e-223
# word:  rapid | prob_word:  0.0015037593984962407 | c_i:  2 | prob:  1.063918289115769e-228
# word:  pace | prob_word:  1e-06 | c_i:  2 | prob:  1.063918289115769e-240
# word:  events | prob_word:  0.002255639097744361 | c_i:  2 | prob:  5.413118097146205e-246
# word:  continues | prob_word:  0.0037593984962406013 | c_i:  4 | prob:  1.0812371412580981e-255
# word:  shape | prob_word:  0.0007518796992481203 | c_i:  1 | prob:  8.129602565850363e-259
# word:  our | prob_word:  0.0007518796992481203 | c_i:  1 | prob:  6.112483132218318e-262
# word:  daily | prob_word:  1e-06 | c_i:  1 | prob:  6.112483132218317e-268
# word:  lives | prob_word:  1e-06 | c_i:  1 | prob:  6.112483132218317e-274
# word:  unexpected | prob_word:  1e-06 | c_i:  1 | prob:  6.112483132218317e-280
# word:  ways | prob_word:  1e-06 | c_i:  1 | prob:  6.1124831322183165e-286
# word:  political | prob_word:  0.0030075187969924814 | c_i:  3 | prob:  1.6628103717741936e-293
# word:  power | prob_word:  0.0007518796992481203 | c_i:  5 | prob:  3.995623142831417e-309
# word:  shifts | prob_word:  0.002255639097744361 | c_i:  2 | prob:  2.032936191e-314
# word:  economic | prob_word:  0.004511278195488722 | c_i:  8 | prob:  0.0
# word:  struggles | prob_word:  1e-06 | c_i:  3 | prob:  0.0
# word:  technological | prob_word:  0.0037593984962406013 | c_i:  4 | prob:  0.0
# word:  breakthroughs | prob_word:  0.0015037593984962407 | c_i:  2 | prob:  0.0
# word:  environmental | prob_word:  0.0037593984962406013 | c_i:  2 | prob:  0.0
# word:  concerns | prob_word:  0.002255639097744361 | c_i:  5 | prob:  0.0
# word:  all | prob_word:  1e-06 | c_i:  1 | prob:  0.0
# word:  collide | prob_word:  1e-06 | c_i:  1 | prob:  0.0
# word:  complex | prob_word:  0.0007518796992481203 | c_i:  1 | prob:  0.0
# word:  web | prob_word:  1e-06 | c_i:  1 | prob:  0.0
# word:  demands | prob_word:  1e-06 | c_i:  2 | prob:  0.0
# word:  constant | prob_word:  1e-06 | c_i:  1 | prob:  0.0
# word:  attention | prob_word:  0.0007518796992481203 | c_i:  1 | prob:  0.0
# word:  as | prob_word:  0.006766917293233083 | c_i:  9 | prob:  0.0
# word:  we | prob_word:  0.0015037593984962407 | c_i:  4 | prob:  0.0
# word:  move | prob_word:  0.0007518796992481203 | c_i:  1 | prob:  0.0
# word:  deeper | prob_word:  1e-06 | c_i:  1 | prob:  0.0
# word:  into | prob_word:  0.002255639097744361 | c_i:  3 | prob:  0.0
# word:  understanding | prob_word:  0.0007518796992481203 | c_i:  2 | prob:  0.0
# word:  current | prob_word:  0.0015037593984962407 | c_i:  1 | prob:  0.0
# word:  is | prob_word:  0.006015037593984963 | c_i:  19 | prob:  0.0
# word:  more | prob_word:  0.0015037593984962407 | c_i:  4 | prob:  0.0
# word:  important | prob_word:  1e-06 | c_i:  1 | prob:  0.0
# word:  than | prob_word:  1e-06 | c_i:  1 | prob:  0.0
# word:  ever | prob_word:  1e-06 | c_i:  1 | prob:  0.0
# word:  not | prob_word:  1e-06 | c_i:  1 | prob:  0.0
# word:  just | prob_word:  1e-06 | c_i:  1 | prob:  0.0
# word:  for | prob_word:  0.009774436090225564 | c_i:  11 | prob:  0.0
# word:  governments | prob_word:  0.0030075187969924814 | c_i:  3 | prob:  0.0
# word:  policymakers | prob_word:  0.0007518796992481203 | c_i:  1 | prob:  0.0
# word:  but | prob_word:  0.0007518796992481203 | c_i:  9 | prob:  0.0
# word:  every | prob_word:  1e-06 | c_i:  2 | prob:  0.0
# word:  individual | prob_word:  1e-06 | c_i:  2 | prob:  0.0
# word:  who | prob_word:  1e-06 | c_i:  1 | prob:  0.0
# word:  seeks | prob_word:  1e-06 | c_i:  1 | prob:  0.0
# word:  navigate | prob_word:  0.0007518796992481203 | c_i:  1 | prob:  0.0
# word:  an | prob_word:  1e-06 | c_i:  1 | prob:  0.0
# word:  increasingly | prob_word:  0.0007518796992481203 | c_i:  1 | prob:  0.0
# word:  interconnected | prob_word:  0.0007518796992481203 | c_i:  1 | prob:  0.0
# word:  upheavals | prob_word:  1e-06 | c_i:  1 | prob:  0.0
# word:  diplomatic | prob_word:  0.002255639097744361 | c_i:  3 | prob:  0.0
# word:  maneuvers | prob_word:  1e-06 | c_i:  1 | prob:  0.0
# word:  conflict | prob_word:  1e-06 | c_i:  3 | prob:  0.0
# word:  zones | prob_word:  1e-06 | c_i:  1 | prob:  0.0
# word:  russiaukraine | prob_word:  0.0015037593984962407 | c_i:  1 | prob:  0.0
# word:  war | prob_word:  0.002255639097744361 | c_i:  2 | prob:  0.0
# word:  persists | prob_word:  1e-06 | c_i:  1 | prob:  0.0
# word:  defining | prob_word:  1e-06 | c_i:  1 | prob:  0.0
# word:  modern | prob_word:  1e-06 | c_i:  2 | prob:  0.0
# word:  era | prob_word:  1e-06 | c_i:  1 | prob:  0.0
# word:  with | prob_word:  0.016541353383458645 | c_i:  12 | prob:  0.0
# word:  no | prob_word:  0.0007518796992481203 | c_i:  3 | prob:  0.0
# word:  clear | prob_word:  0.0007518796992481203 | c_i:  1 | prob:  0.0
# word:  resolution | prob_word:  0.0007518796992481203 | c_i:  1 | prob:  0.0
# word:  sight | prob_word:  0.0007518796992481203 | c_i:  1 | prob:  0.0
# word:  ukraine | prob_word:  0.0015037593984962407 | c_i:  1 | prob:  0.0
# word:  backed | prob_word:  1e-06 | c_i:  1 | prob:  0.0
# word:  by | prob_word:  0.002255639097744361 | c_i:  2 | prob:  0.0
# word:  western | prob_word:  0.0015037593984962407 | c_i:  1 | prob:  0.0
# word:  nations | prob_word:  0.004511278195488722 | c_i:  3 | prob:  0.0
# word:  its | prob_word:  0.0037593984962406013 | c_i:  9 | prob:  0.0
# word:  struggle | prob_word:  1e-06 | c_i:  1 | prob:  0.0
# word:  sovereignty | prob_word:  1e-06 | c_i:  1 | prob:  0.0
# word:  while | prob_word:  0.005263157894736842 | c_i:  7 | prob:  0.0
# word:  russia | prob_word:  0.0015037593984962407 | c_i:  1 | prob:  0.0
# word:  remains | prob_word:  0.005263157894736842 | c_i:  7 | prob:  0.0
# word:  determined | prob_word:  1e-06 | c_i:  1 | prob:  0.0
# word:  secure | prob_word:  1e-06 | c_i:  1 | prob:  0.0
# word:  strategic | prob_word:  1e-06 | c_i:  1 | prob:  0.0
# word:  interests | prob_word:  1e-06 | c_i:  1 | prob:  0.0
# word:  sanctions | prob_word:  0.0007518796992481203 | c_i:  1 | prob:  0.0
# word:  on | prob_word:  0.005263157894736842 | c_i:  7 | prob:  0.0
# word:  moscow | prob_word:  1e-06 | c_i:  1 | prob:  0.0
# word:  have | prob_word:  0.0007518796992481203 | c_i:  6 | prob:  0.0
# word:  crippled | prob_word:  1e-06 | c_i:  1 | prob:  0.0
# word:  certain | prob_word:  0.0007518796992481203 | c_i:  2 | prob:  0.0
# word:  sectors | prob_word:  0.0015037593984962407 | c_i:  1 | prob:  0.0
# word:  economy | prob_word:  0.0007518796992481203 | c_i:  3 | prob:  0.0
# word:  yet | prob_word:  1e-06 | c_i:  2 | prob:  0.0
# word:  markets | prob_word:  0.002255639097744361 | c_i:  3 | prob:  0.0
# word:  remain | prob_word:  0.002255639097744361 | c_i:  7 | prob:  0.0
# word:  deeply | prob_word:  0.0007518796992481203 | c_i:  1 | prob:  0.0
# word:  affected | prob_word:  1e-06 | c_i:  1 | prob:  0.0
# word:  energy | prob_word:  0.0037593984962406013 | c_i:  4 | prob:  0.0
# word:  shortages | prob_word:  1e-06 | c_i:  1 | prob:  0.0
# word:  rippling | prob_word:  1e-06 | c_i:  1 | prob:  0.0
# word:  across | prob_word:  1e-06 | c_i:  1 | prob:  0.0
# word:  continents | prob_word:  1e-06 | c_i:  1 | prob:  0.0
# word:  meanwhile | prob_word:  0.0015037593984962407 | c_i:  3 | prob:  0.0
# word:  international | prob_word:  0.0030075187969924814 | c_i:  2 | prob:  0.0
# word:  channels | prob_word:  1e-06 | c_i:  1 | prob:  0.0
# word:  active | prob_word:  1e-06 | c_i:  1 | prob:  0.0
# word:  ceasefire | prob_word:  1e-06 | c_i:  1 | prob:  0.0
# word:  negotiations | prob_word:  1e-06 | c_i:  1 | prob:  0.0
# word:  made | prob_word:  1e-06 | c_i:  1 | prob:  0.0
# word:  little | prob_word:  1e-06 | c_i:  1 | prob:  0.0
# word:  tangible | prob_word:  1e-06 | c_i:  1 | prob:  0.0
# word:  progress | prob_word:  0.0015037593984962407 | c_i:  2 | prob:  0.0
# word:  elsewhere | prob_word:  1e-06 | c_i:  1 | prob:  0.0
# word:  tensions | prob_word:  0.0015037593984962407 | c_i:  2 | prob:  0.0
# word:  between | prob_word:  0.002255639097744361 | c_i:  2 | prob:  0.0
# word:  china | prob_word:  0.0015037593984962407 | c_i:  3 | prob:  0.0
# word:  taiwan | prob_word:  0.0007518796992481203 | c_i:  1 | prob:  0.0
# word:  escalated | prob_word:  1e-06 | c_i:  1 | prob:  0.0
# word:  drawing | prob_word:  1e-06 | c_i:  1 | prob:  0.0
# word:  united | prob_word:  0.0007518796992481203 | c_i:  3 | prob:  0.0
# word:  states | prob_word:  0.0007518796992481203 | c_i:  3 | prob:  0.0
# word:  allies | prob_word:  1e-06 | c_i:  1 | prob:  0.0
# word:  precarious | prob_word:  1e-06 | c_i:  1 | prob:  0.0
# word:  game | prob_word:  1e-06 | c_i:  2 | prob:  0.0
# word:  military | prob_word:  0.0015037593984962407 | c_i:  1 | prob:  0.0
# word:  posturing | prob_word:  1e-06 | c_i:  1 | prob:  0.0
# word:  flexes | prob_word:  1e-06 | c_i:  1 | prob:  0.0
# word:  naval | prob_word:  1e-06 | c_i:  1 | prob:  0.0
# word:  indopacific | prob_word:  0.0007518796992481203 | c_i:  2 | prob:  0.0
# word:  such | prob_word:  0.0030075187969924814 | c_i:  1 | prob:  0.0
# word:  japan | prob_word:  0.0007518796992481203 | c_i:  1 | prob:  0.0
# word:  south | prob_word:  0.0015037593984962407 | c_i:  1 | prob:  0.0
# word:  korea | prob_word:  0.0007518796992481203 | c_i:  1 | prob:  0.0
# word:  bolster | prob_word:  1e-06 | c_i:  1 | prob:  0.0
# word:  their | prob_word:  0.0007518796992481203 | c_i:  4 | prob:  0.0
# word:  defenses | prob_word:  1e-06 | c_i:  1 | prob:  0.0
# word:  preparing | prob_word:  1e-06 | c_i:  1 | prob:  0.0
# word:  potential | prob_word:  0.0015037593984962407 | c_i:  4 | prob:  0.0
# word:  question | prob_word:  1e-06 | c_i:  1 | prob:  0.0
# word:  will | prob_word:  0.0015037593984962407 | c_i:  4 | prob:  0.0
# word:  talks | prob_word:  0.0007518796992481203 | c_i:  1 | prob:  0.0
# word:  diffuse | prob_word:  1e-06 | c_i:  1 | prob:  0.0
# word:  situation | prob_word:  1e-06 | c_i:  1 | prob:  0.0
# word:  or | prob_word:  1e-06 | c_i:  2 | prob:  0.0
# word:  greater | prob_word:  1e-06 | c_i:  1 | prob:  0.0
# word:  confrontation | prob_word:  1e-06 | c_i:  1 | prob:  0.0
# word:  inevitable | prob_word:  1e-06 | c_i:  1 | prob:  0.0
# word:  role | prob_word:  0.002255639097744361 | c_i:  2 | prob:  0.0
# word:  superpowers | prob_word:  1e-06 | c_i:  1 | prob:  0.0
# word:  stability | prob_word:  0.0007518796992481203 | c_i:  1 | prob:  0.0
# word:  dominant | prob_word:  0.0007518796992481203 | c_i:  1 | prob:  0.0
# word:  force | prob_word:  1e-06 | c_i:  1 | prob:  0.0
# word:  stage | prob_word:  1e-06 | c_i:  1 | prob:  0.0
# ...
# word:  media | prob_word:  0.0015037593984962407 | c_i:  1 | prob:  0.0
# word:  entertainment | prob_word:  1e-06 | c_i:  1 | prob:  0.0
# word:  customer | prob_word:  0.0007518796992481203 | c_i:  1 | prob:  0.0
# word:  service | prob_word:  0.0007518796992481203 | c_i:  1 | prob:  0.0
# word:  however | prob_word:  0.0030075187969924814 | c_i:  3 | prob:  0.0
# word:  job | prob_word:  0.002255639097744361 | c_i:  2 | prob:  0.0
# word:  displacement | prob_word:  0.0007518796992481203 | c_i:  1 | prob:  0.0
# word:  ethical | prob_word:  1e-06 | c_i:  2 | prob:  0.0
# word:  dilemmas | prob_word:  1e-06 | c_i:  1 | prob:  0.0
# word:  at | prob_word:  1e-06 | c_i:  3 | prob:  0.0
# word:  forefront | prob_word:  1e-06 | c_i:  1 | prob:  0.0
# word:  discussions | prob_word:  1e-06 | c_i:  1 | prob:  0.0
# word:  scrambling | prob_word:  1e-06 | c_i:  1 | prob:  0.0
# word:  regulations | prob_word:  0.0007518796992481203 | c_i:  1 | prob:  0.0
# word:  aiming | prob_word:  1e-06 | c_i:  1 | prob:  0.0
# word:  balance | prob_word:  1e-06 | c_i:  1 | prob:  0.0
# word:  security | prob_word:  0.0007518796992481203 | c_i:  2 | prob:  0.0
# word:  space | prob_word:  0.0030075187969924814 | c_i:  6 | prob:  0.0
# word:  exploration | prob_word:  0.0030075187969924814 | c_i:  2 | prob:  0.0
# word:  new | prob_word:  0.002255639097744361 | c_i:  5 | prob:  0.0
# word:  race | prob_word:  1e-06 | c_i:  1 | prob:  0.0
# word:  humanitys | prob_word:  1e-06 | c_i:  1 | prob:  0.0
# word:  ambitions | prob_word:  1e-06 | c_i:  1 | prob:  0.0
# word:  reaching | prob_word:  1e-06 | c_i:  1 | prob:  0.0
# word:  heights | prob_word:  1e-06 | c_i:  1 | prob:  0.0
# word:  artemis | prob_word:  0.0007518796992481203 | c_i:  1 | prob:  0.0
# word:  program | prob_word:  0.0015037593984962407 | c_i:  2 | prob:  0.0
# word:  track | prob_word:  1e-06 | c_i:  1 | prob:  0.0
# word:  return | prob_word:  1e-06 | c_i:  1 | prob:  0.0
# word:  humans | prob_word:  0.0007518796992481203 | c_i:  1 | prob:  0.0
# word:  moon | prob_word:  0.0007518796992481203 | c_i:  1 | prob:  0.0
# word:  spacex | prob_word:  0.0007518796992481203 | c_i:  1 | prob:  0.0
# word:  private | prob_word:  0.0007518796992481203 | c_i:  1 | prob:  0.0
# word:  companies | prob_word:  0.0015037593984962407 | c_i:  1 | prob:  0.0
# word:  push | prob_word:  0.0007518796992481203 | c_i:  1 | prob:  0.0
# word:  boundaries | prob_word:  1e-06 | c_i:  2 | prob:  0.0
# word:  commercial | prob_word:  0.0015037593984962407 | c_i:  1 | prob:  0.0
# word:  travel | prob_word:  1e-06 | c_i:  1 | prob:  0.0
# word:  too | prob_word:  1e-06 | c_i:  1 | prob:  0.0
# word:  intensified | prob_word:  1e-06 | c_i:  1 | prob:  0.0
# word:  plans | prob_word:  1e-06 | c_i:  1 | prob:  0.0
# word:  mars | prob_word:  0.0007518796992481203 | c_i:  1 | prob:  0.0
# word:  expanded | prob_word:  1e-06 | c_i:  1 | prob:  0.0
# word:  lunar | prob_word:  1e-06 | c_i:  1 | prob:  0.0
# word:  missions | prob_word:  0.0015037593984962407 | c_i:  1 | prob:  0.0
# word:  advances | prob_word:  0.0007518796992481203 | c_i:  2 | prob:  0.0
# word:  arise | prob_word:  1e-06 | c_i:  1 | prob:  0.0
# word:  colonization | prob_word:  1e-06 | c_i:  1 | prob:  0.0
# word:  governance | prob_word:  1e-06 | c_i:  1 | prob:  0.0
# word:  extraterrestrial | prob_word:  1e-06 | c_i:  1 | prob:  0.0
# word:  resources | prob_word:  0.0007518796992481203 | c_i:  1 | prob:  0.0
# word:  climate | prob_word:  0.0030075187969924814 | c_i:  4 | prob:  0.0
# word:  action | prob_word:  1e-06 | c_i:  3 | prob:  0.0
# word:  warming | prob_word:  1e-06 | c_i:  1 | prob:  0.0
# word:  extreme | prob_word:  0.0007518796992481203 | c_i:  1 | prob:  0.0
# word:  weather | prob_word:  0.0007518796992481203 | c_i:  1 | prob:  0.0
# word:  effects | prob_word:  1e-06 | c_i:  1 | prob:  0.0
# word:  change | prob_word:  0.002255639097744361 | c_i:  2 | prob:  0.0
# word:  distant | prob_word:  1e-06 | c_i:  1 | prob:  0.0
# word:  threatsthey | prob_word:  1e-06 | c_i:  1 | prob:  0.0
# word:  happening | prob_word:  1e-06 | c_i:  1 | prob:  0.0
# word:  wildfires | prob_word:  0.0007518796992481203 | c_i:  1 | prob:  0.0
# word:  hurricanes | prob_word:  0.0007518796992481203 | c_i:  1 | prob:  0.0
# word:  heatwaves | prob_word:  0.0007518796992481203 | c_i:  1 | prob:  0.0
# word:  becoming | prob_word:  0.0015037593984962407 | c_i:  2 | prob:  0.0
# word:  frequent | prob_word:  1e-06 | c_i:  1 | prob:  0.0
# word:  reevaluate | prob_word:  1e-06 | c_i:  1 | prob:  0.0
# word:  latest | prob_word:  1e-06 | c_i:  1 | prob:  0.0
# word:  summits | prob_word:  1e-06 | c_i:  1 | prob:  0.0
# word:  seen | prob_word:  0.0007518796992481203 | c_i:  1 | prob:  0.0
# word:  renewed | prob_word:  1e-06 | c_i:  1 | prob:  0.0
# word:  commitments | prob_word:  0.0007518796992481203 | c_i:  1 | prob:  0.0
# word:  carbon | prob_word:  0.0007518796992481203 | c_i:  1 | prob:  0.0
# word:  neutrality | prob_word:  0.0007518796992481203 | c_i:  1 | prob:  0.0
# word:  gap | prob_word:  1e-06 | c_i:  1 | prob:  0.0
# word:  promises | prob_word:  1e-06 | c_i:  1 | prob:  0.0
# word:  wide | prob_word:  1e-06 | c_i:  1 | prob:  0.0
# word:  renewable | prob_word:  0.0015037593984962407 | c_i:  2 | prob:  0.0
# word:  vs | prob_word:  1e-06 | c_i:  1 | prob:  0.0
# word:  fossil | prob_word:  1e-06 | c_i:  2 | prob:  0.0
# word:  fuels | prob_word:  1e-06 | c_i:  1 | prob:  0.0
# word:  transition | prob_word:  0.0007518796992481203 | c_i:  1 | prob:  0.0
# word:  accelerating | prob_word:  0.0015037593984962407 | c_i:  1 | prob:  0.0
# word:  wield | prob_word:  1e-06 | c_i:  1 | prob:  0.0
# word:  significant | prob_word:  0.0030075187969924814 | c_i:  1 | prob:  0.0
# word:  influence | prob_word:  0.0007518796992481203 | c_i:  2 | prob:  0.0
# word:  solar | prob_word:  0.0007518796992481203 | c_i:  1 | prob:  0.0
# word:  wind | prob_word:  0.0007518796992481203 | c_i:  1 | prob:  0.0
# word:  installations | prob_word:  1e-06 | c_i:  1 | prob:  0.0
# word:  worlds | prob_word:  1e-06 | c_i:  1 | prob:  0.0
# word:  heavily | prob_word:  1e-06 | c_i:  1 | prob:  0.0
# word:  reliant | prob_word:  0.0007518796992481203 | c_i:  1 | prob:  0.0
# word:  oil | prob_word:  1e-06 | c_i:  1 | prob:  0.0
# word:  gas | prob_word:  0.0007518796992481203 | c_i:  1 | prob:  0.0
# word:  debate | prob_word:  0.0007518796992481203 | c_i:  2 | prob:  0.0
# word:  nuclear | prob_word:  0.0015037593984962407 | c_i:  2 | prob:  0.0
# word:  energys | prob_word:  1e-06 | c_i:  1 | prob:  0.0
# word:  sustainable | prob_word:  0.0007518796992481203 | c_i:  1 | prob:  0.0
# word:  also | prob_word:  0.0007518796992481203 | c_i:  3 | prob:  0.0
# word:  heating | prob_word:  1e-06 | c_i:  1 | prob:  0.0
# word:  up | prob_word:  0.0015037593984962407 | c_i:  1 | prob:  0.0
# word:  some | prob_word:  0.0007518796992481203 | c_i:  2 | prob:  0.0
# word:  expanding | prob_word:  0.0007518796992481203 | c_i:  1 | prob:  0.0
# word:  programs | prob_word:  1e-06 | c_i:  1 | prob:  0.0
# word:  others | prob_word:  1e-06 | c_i:  1 | prob:  0.0
# word:  hesitant | prob_word:  1e-06 | c_i:  1 | prob:  0.0
# word:  due | prob_word:  0.0015037593984962407 | c_i:  1 | prob:  0.0
# word:  safety | prob_word:  1e-06 | c_i:  1 | prob:  0.0
# word:  social | prob_word:  0.0037593984962406013 | c_i:  4 | prob:  0.0
# word:  transformations | prob_word:  1e-06 | c_i:  1 | prob:  0.0
# word:  cultural | prob_word:  0.0007518796992481203 | c_i:  1 | prob:  0.0
# word:  revolution | prob_word:  1e-06 | c_i:  1 | prob:  0.0
# word:  life | prob_word:  1e-06 | c_i:  1 | prob:  0.0
# word:  remote | prob_word:  0.0015037593984962407 | c_i:  1 | prob:  0.0
# word:  work | prob_word:  0.0037593984962406013 | c_i:  2 | prob:  0.0
# word:  banking | prob_word:  0.0007518796992481203 | c_i:  1 | prob:  0.0
# word:  reshape | prob_word:  1e-06 | c_i:  1 | prob:  0.0
# word:  how | prob_word:  1e-06 | c_i:  2 | prob:  0.0
# word:  live | prob_word:  1e-06 | c_i:  1 | prob:  0.0
# word:  gig | prob_word:  0.0007518796992481203 | c_i:  1 | prob:  0.0
# word:  creating | prob_word:  1e-06 | c_i:  1 | prob:  0.0
# word:  opportunities | prob_word:  0.0007518796992481203 | c_i:  2 | prob:  0.0
# word:  labor | prob_word:  0.0015037593984962407 | c_i:  1 | prob:  0.0
# word:  rights | prob_word:  0.002255639097744361 | c_i:  4 | prob:  0.0
# word:  medias | prob_word:  1e-06 | c_i:  1 | prob:  0.0
# word:  politics | prob_word:  0.0007518796992481203 | c_i:  1 | prob:  0.0
# word:  public | prob_word:  0.0015037593984962407 | c_i:  1 | prob:  0.0
# word:  opinion | prob_word:  1e-06 | c_i:  1 | prob:  0.0
# word:  strong | prob_word:  1e-06 | c_i:  1 | prob:  0.0
# word:  misinformation | prob_word:  0.0007518796992481203 | c_i:  1 | prob:  0.0
# word:  campaigns | prob_word:  1e-06 | c_i:  1 | prob:  0.0
# word:  posing | prob_word:  1e-06 | c_i:  1 | prob:  0.0
# word:  persistent | prob_word:  1e-06 | c_i:  1 | prob:  0.0
# word:  challenge | prob_word:  0.0007518796992481203 | c_i:  1 | prob:  0.0
# word:  human | prob_word:  0.002255639097744361 | c_i:  3 | prob:  0.0
# word:  justice | prob_word:  0.0007518796992481203 | c_i:  1 | prob:  0.0
# word:  movements | prob_word:  0.0015037593984962407 | c_i:  2 | prob:  0.0
# word:  globally | prob_word:  1e-06 | c_i:  1 | prob:  0.0
# word:  advocating | prob_word:  1e-06 | c_i:  1 | prob:  0.0
# word:  racial | prob_word:  0.0007518796992481203 | c_i:  1 | prob:  0.0
# word:  equality | prob_word:  0.0007518796992481203 | c_i:  1 | prob:  0.0
# word:  gender | prob_word:  0.0007518796992481203 | c_i:  1 | prob:  0.0
# word:  freedom | prob_word:  0.0007518796992481203 | c_i:  2 | prob:  0.0
# word:  speech | prob_word:  0.0007518796992481203 | c_i:  1 | prob:  0.0
# word:  gain | prob_word:  1e-06 | c_i:  1 | prob:  0.0
# word:  regions | prob_word:  0.0030075187969924814 | c_i:  1 | prob:  0.0
# word:  authoritarian | prob_word:  0.0007518796992481203 | c_i:  1 | prob:  0.0
# word:  regimes | prob_word:  0.0007518796992481203 | c_i:  1 | prob:  0.0
# word:  cracking | prob_word:  1e-06 | c_i:  1 | prob:  0.0
# word:  down | prob_word:  1e-06 | c_i:  1 | prob:  0.0
# word:  dissent | prob_word:  1e-06 | c_i:  1 | prob:  0.0
# word:  limiting | prob_word:  1e-06 | c_i:  1 | prob:  0.0
# word:  press | prob_word:  1e-06 | c_i:  1 | prob:  0.0
# word:  suppressing | prob_word:  1e-06 | c_i:  1 | prob:  0.0
# word:  activism | prob_word:  0.0015037593984962407 | c_i:  1 | prob:  0.0
# word:  fight | prob_word:  1e-06 | c_i:  1 | prob:  0.0
# word:  democracy | prob_word:  1e-06 | c_i:  1 | prob:  0.0
# word:  critical | prob_word:  0.002255639097744361 | c_i:  1 | prob:  0.0
# word:  issue | prob_word:  0.0015037593984962407 | c_i:  1 | prob:  0.0
# word:  worldwide | prob_word:  0.0015037593984962407 | c_i:  2 | prob:  0.0
# word:  health | prob_word:  0.004511278195488722 | c_i:  4 | prob:  0.0
# word:  scientific | prob_word:  0.002255639097744361 | c_i:  1 | prob:  0.0
# word:  postpandemic | prob_word:  0.0007518796992481203 | c_i:  1 | prob:  0.0
# word:  covid | prob_word:  0.0007518796992481203 | c_i:  1 | prob:  0.0
# word:  pandemic | prob_word:  0.0007518796992481203 | c_i:  1 | prob:  0.0
# word:  largely | prob_word:  0.0007518796992481203 | c_i:  1 | prob:  0.0
# word:  subsided | prob_word:  0.0007518796992481203 | c_i:  1 | prob:  0.0
# word:  emerging | prob_word:  0.0015037593984962407 | c_i:  1 | prob:  0.0
# word:  scientists | prob_word:  1e-06 | c_i:  1 | prob:  0.0
# word:  closely | prob_word:  0.0007518796992481203 | c_i:  1 | prob:  0.0
# word:  monitoring | prob_word:  0.0007518796992481203 | c_i:  1 | prob:  0.0
# word:  virus | prob_word:  1e-06 | c_i:  1 | prob:  0.0
# word:  outbreaks | prob_word:  0.0007518796992481203 | c_i:  1 | prob:  0.0
# word:  mental | prob_word:  0.0030075187969924814 | c_i:  1 | prob:  0.0
# word:  awareness | prob_word:  0.0015037593984962407 | c_i:  1 | prob:  0.0
# word:  become | prob_word:  0.0007518796992481203 | c_i:  1 | prob:  0.0
# word:  growing | prob_word:  0.0007518796992481203 | c_i:  1 | prob:  0.0
# word:  concern | prob_word:  0.0015037593984962407 | c_i:  1 | prob:  0.0
# word:  healthcare | prob_word:  0.0015037593984962407 | c_i:  1 | prob:  0.0
# word:  under | prob_word:  0.0007518796992481203 | c_i:  1 | prob:  0.0
# word:  pressure | prob_word:  1e-06 | c_i:  1 | prob:  0.0
# word:  modernize | prob_word:  1e-06 | c_i:  1 | prob:  0.0
# word:  prepare | prob_word:  1e-06 | c_i:  1 | prob:  0.0
# word:  crises | prob_word:  0.0015037593984962407 | c_i:  1 | prob:  0.0
# word:  medical | prob_word:  0.0007518796992481203 | c_i:  1 | prob:  0.0
# word:  innovations | prob_word:  0.0015037593984962407 | c_i:  1 | prob:  0.0
# word:  biotechnology | prob_word:  1e-06 | c_i:  2 | prob:  0.0
# word:  cancer | prob_word:  0.0007518796992481203 | c_i:  1 | prob:  0.0
# word:  treatments | prob_word:  0.0015037593984962407 | c_i:  2 | prob:  0.0
# word:  gene | prob_word:  0.0007518796992481203 | c_i:  2 | prob:  0.0
# word:  editing | prob_word:  1e-06 | c_i:  1 | prob:  0.0
# word:  pushing | prob_word:  0.0007518796992481203 | c_i:  1 | prob:  0.0
# word:  what | prob_word:  1e-06 | c_i:  2 | prob:  0.0
# word:  medically | prob_word:  1e-06 | c_i:  1 | prob:  0.0
# word:  personalized | prob_word:  0.0007518796992481203 | c_i:  1 | prob:  0.0
# word:  medicine | prob_word:  0.0015037593984962407 | c_i:  1 | prob:  0.0
# word:  accessible | prob_word:  0.0007518796992481203 | c_i:  1 | prob:  0.0
# word:  offering | prob_word:  0.0007518796992481203 | c_i:  1 | prob:  0.0
# word:  targeted | prob_word:  1e-06 | c_i:  1 | prob:  0.0
# word:  tailored | prob_word:  1e-06 | c_i:  1 | prob:  0.0
# word:  genetic | prob_word:  0.0007518796992481203 | c_i:  1 | prob:  0.0
# word:  profiles | prob_word:  1e-06 | c_i:  1 | prob:  0.0
# word:  surrounding | prob_word:  1e-06 | c_i:  1 | prob:  0.0
# word:  modification | prob_word:  1e-06 | c_i:  1 | prob:  0.0
# word:  conclusion | prob_word:  0.0007518796992481203 | c_i:  1 | prob:  0.0
# word:  path | prob_word:  0.0007518796992481203 | c_i:  1 | prob:  0.0
# word:  ahead | prob_word:  1e-06 | c_i:  2 | prob:  0.0
# word:  crossroads | prob_word:  1e-06 | c_i:  1 | prob:  0.0
# word:  facing | prob_word:  0.0007518796992481203 | c_i:  1 | prob:  0.0
# word:  unprecedented | prob_word:  1e-06 | c_i:  1 | prob:  0.0
# word:  immense | prob_word:  0.0007518796992481203 | c_i:  1 | prob:  0.0
# word:  geopolitical | prob_word:  0.004511278195488722 | c_i:  1 | prob:  0.0
# word:  uncertainties | prob_word:  0.0007518796992481203 | c_i:  1 | prob:  0.0
# word:  advancements | prob_word:  0.002255639097744361 | c_i:  1 | prob:  0.0
# word:  reshaping | prob_word:  0.0007518796992481203 | c_i:  1 | prob:  0.0
# word:  society | prob_word:  1e-06 | c_i:  1 | prob:  0.0
# word:  look | prob_word:  1e-06 | c_i:  1 | prob:  0.0
# word:  adaptability | prob_word:  0.0007518796992481203 | c_i:  1 | prob:  0.0
# word:  informed | prob_word:  0.0007518796992481203 | c_i:  2 | prob:  0.0
# word:  decisionmaking | prob_word:  1e-06 | c_i:  1 | prob:  0.0
# word:  be | prob_word:  0.0015037593984962407 | c_i:  2 | prob:  0.0
# word:  crucial | prob_word:  1e-06 | c_i:  1 | prob:  0.0
# word:  navigating | prob_word:  1e-06 | c_i:  1 | prob:  0.0
# word:  whether | prob_word:  1e-06 | c_i:  1 | prob:  0.0
# word:  through | prob_word:  0.0007518796992481203 | c_i:  1 | prob:  0.0
# word:  diplomacy | prob_word:  0.0007518796992481203 | c_i:  1 | prob:  0.0
# word:  collective | prob_word:  1e-06 | c_i:  1 | prob:  0.0
# word:  defined | prob_word:  1e-06 | c_i:  1 | prob:  0.0
# word:  respond | prob_word:  1e-06 | c_i:  1 | prob:  0.0
# word:  todays | prob_word:  1e-06 | c_i:  1 | prob:  0.0
# word:  pressing | prob_word:  0.0007518796992481203 | c_i:  1 | prob:  0.0
# word:  issues | prob_word:  0.0007518796992481203 | c_i:  1 | prob:  0.0
# word:  one | prob_word:  1e-06 | c_i:  1 | prob:  0.0
# word:  thing | prob_word:  1e-06 | c_i:  1 | prob:  0.0
# word:  staying | prob_word:  0.0007518796992481203 | c_i:  1 | prob:  0.0
# word:  key | prob_word:  0.0015037593984962407 | c_i:  1 | prob:  0.0
# word:  comes | prob_word:  1e-06 | c_i:  1 | prob:  0.0
# word:  next | prob_word:  1e-06 | c_i:  1 | prob:  0.0
# Hamilton Term	 0.0
# Madison Term	 0.0

# %%
import csv
from itertools import count
import operator
import math

EPSILON = 0.000001

def main():
    # Calculate all the ps and qs
    # Eg hamiltonWordProb['congress'] = 0.005
    # hamilton_word_prob['piech'] = 0.0
    # hamilton_word_prob['the'] = 0.001

    hamilton_word_prob = make_word_prob_map('hamilton.txt')
    madison_word_prob = make_word_prob_map('madison.txt')

    

    # Get the word count of the unknown document
    # Eg unknown_doc_count['congress'] = 5
    unknown_doc_count, n_words = make_word_count_map('unknown.txt')

    #print("hamilton['congress']\t", hamilton_word_prob['congress'])
    #print("madison['congress']\t",  madison_word_prob['congress'])
    #print("doc_count['congress']\t", unknown_doc_count['congress'])
    print("n_words", n_words)

    hamilton_term = calc_log_pr_doc_given_author(hamilton_word_prob, unknown_doc_count)
    madison_term = calc_log_pr_doc_given_author(madison_word_prob, unknown_doc_count)
    print("log P(D|H)\t", hamilton_term)
    print("log P(D|M)\t",madison_term)

    print('diff\t', hamilton_term - madison_term)

def calc_log_pr_doc_given_author(prob_map, counts):
    """
    How likely is the document, given the counts of words in the doc
    and the authors prob_map
    """
    log_prob = math.log(1)
    for word_i, c_i in counts.items():
        p_i = get_word_prob(prob_map, word_i)
        log_prob += c_i * math.log(p_i)
    return log_prob


def calcLogProbDoc(wordProbMap, countMap):
    logProb = math.log(1)
    for wordi in countMap:
        ci = countMap[wordi]
        pi = get_word_prob(wordProbMap, wordi)
        logProb += ci * math.log(pi)
    return logProb

# If a word is in a probability dictionary, return its probability
# otherwise, return epsilon
def get_word_prob(word_prob_map, word):
    if word in word_prob_map:
        return word_prob_map[word]
    return EPSILON

# From a file name, approximate the probability of a word
# being generated from the same distribution as the file.
# Assume that each word is produced independently, regardless
# of order.
def make_word_prob_map(fileName):
    wordMap, nWords = make_word_count_map(fileName)
    probabilityMap = {}
    for word in wordMap:
        count = wordMap[word]
        p = float(count) / nWords
        probabilityMap[word] = p
    return probabilityMap

# From a file name, count the number of times each word exists
# in that file. Return the result as a map (aka a dictionary)
def make_word_count_map(fileName):
    wordMap = {}
    nWords = 0
    with open(fileName , encoding='utf-8') as f:
        for line in f:
            words = line.split(' ')
            for word in words:
                word = standardize(word)
                add_word_to_count_map(wordMap, word)
                nWords+= 1
    return wordMap, nWords

# Add a word to a count map. Makes sure not to crash if the
# word has not been seen before.
def add_word_to_count_map(wordMap, word):
    if not word in wordMap:
        wordMap[word] = 0
    wordMap[word] += 1 

# Standardizes a word. For now, we are just going to make it
# lower case.
def standardize(word):
    standard = word.lower().strip()
    # remove punctuation
    standard = ''.join([i for i in standard if i.isalpha()])
    return standard

if __name__ == '__main__':
    main()
# Out:
# n_words 2172
# log P(D|H)	 -14251.749082287015
# log P(D|M)	 -12898.137397440358
# diff	 -1353.6116848466572
